# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/144File(with~as)_145File(seek%2Cread%2Cwrite).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 144 예제
with open('stockcode.txt','r')as f:
  for line_num,line in enumerate(f.readlines()):
    print('%d %s'%(line_num+1,line),end='')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2851477880.py in <cell line: 0>()
#       1 #Unite 144 예제
# ----> 2 with open('stockcode.txt','r')as f:
#       3   for line_num,line in enumerate(f.readlines()):
#       4     print('%d %s'%(line_num+1,line),end='')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stockcode.txt'

# %%
#Unite 145 예제
spos=105
size=500

f=open('stockcode.txt','r')
h=open(('stockcode_part.txt','w'))

f=seek(spos)
data=f,read(size)
h.write(data)

h.close()
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3984987954.py in <cell line: 0>()
#       3 size=500
#       4
# ----> 5 f=open('stockcode.txt','r')
#       6 h=open(('stockcode_part.txt','w'))
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stockcode.txt'
