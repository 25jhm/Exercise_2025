# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/118List(sorted)_119List(shuffle).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 118 예제
namelist=['Mary','Sams','Aimy','Tom','Michale','Bob','Keiiy']
ret1=sorted(namelist)
ret2=sorted(namelist,reverse=True)
print(namelist)
print(ret1)
print(ret2)
# Out:
# ['Mary', 'Sams', 'Aimy', 'Tom', 'Michale', 'Bob', 'Keiiy']
# ['Aimy', 'Bob', 'Keiiy', 'Mary', 'Michale', 'Sams', 'Tom']
# ['Tom', 'Sams', 'Michale', 'Mary', 'Keiiy', 'Bob', 'Aimy']

# %%
#Unite 119 예제
from random import shuffle

listdata=list(range(1,11))
for i in range(3):
  shuffle(listdata)
  print(listdata)
# Out:
# [6, 4, 7, 2, 9, 8, 5, 1, 3, 10]
# [10, 2, 6, 8, 9, 1, 3, 4, 5, 7]
# [7, 6, 8, 3, 4, 1, 2, 9, 10, 5]
