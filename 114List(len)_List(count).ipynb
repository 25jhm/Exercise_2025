# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/114List(len)_List(count).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 114 예제
listdata=[2,2,1,3,8,5,7,6,3,6,2,3,9,4,4]
listsize=len(listdata)
print(listsize)
# Out:
# 15

# %%
#Unite 115 예제
listdata=[2,2,1,3,8,5,7,6,3,6,2,3,9,4,4]
c1=listdata.count(2)
c2=listdata.count(7)
print(c1)
print(c2)
# Out:
# 3
# 1
