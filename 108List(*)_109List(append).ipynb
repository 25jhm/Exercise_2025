# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/108List(*)_109List(append).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 108 예제
listdata=list(range(3))
ret=listdata*3
print(ret)
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2]

# %%
#Unite 109 예제
listdata=[]
for i in range(3):
  txt=input('리스트에 추가할 값을 입력하시오[%d/3]:'%(i+1))
  listdata.append(txt)
  print(listdata)
# Out:
# 리스트에 추가할 값을 입력하시오[1/3]:12
# ['12']
# 리스트에 추가할 값을 입력하시오[2/3]:14
# ['12', '14']
# 리스트에 추가할 값을 입력하시오[3/3]:18
# ['12', '14', '18']
