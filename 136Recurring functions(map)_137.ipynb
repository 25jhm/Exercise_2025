# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/136Recurring%20functions(map)_137.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 136 예제
f=lambda x:x*x
args=[1,2,3,4,5]
ret=map(f,args)
print(list(ret))
# Out:
# [1, 4, 9, 16, 25]
