# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/146File(os.path.getsize)_147File(os.remove).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 146 예제
from os.path import getsize

file1='stockcode.txt'
file2='d:/devlab/py200/img_sample.jpg'
file_size1=getsize(file1)
file_size2=getsize(file2)

print('File Name:%s\tFile Size:%d'%(file1,file_size1))
print('File Name:%s\tFile Size:%d'%(file2,file_size2))
#에러가 난 이유 파일이 없어서 코드는 맞았다.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2332107193.py in <cell line: 0>()
#       4 file1='stockcode.txt'
#       5 file2='d:/devlab/py200/img_sample.jpg'
# ----> 6 file_size1=getsize(file1)
#       7 file_size2=getsize(file2)
#       8
#
# /usr/lib/python3.12/genericpath.py in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stockcode.txt'

# %%
#Unite 147 예제
from os import remove

target_file='stockcode_copy,txt'
k=input('[%s]파일을 삭제하시겠습니까?(y/n)'%target_file)
if k=='y':
  remove(target_file)
  print('[%s]를 삭제했습니다.'%target_file)
# Out:
# [stockcode_copy,txt]파일을 삭제하시겠습니까?(y/n)y
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2538645234.py in <cell line: 0>()
#       5 k=input('[%s]파일을 삭제하시겠습니까?(y/n)'%target_file)
#       6 if k=='y':
# ----> 7   remove(target_file)
#       8   print('[%s]를 삭제했습니다.'%target_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stockcode_copy,txt'
