# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/112List(remove)_113List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 112 예제
solarsys=['태양','수성','금성','지구','화성','목성','토성','천왕성','해왕성']
solarsys.remove('태양')
print(solarsys)
# Out:
# ['수성', '금성', '지구', '화성', '목성', '토성', '천왕성', '해왕성']

# %%
#Unite 113 예제
solarsys=['태양','수성','금성','지구','화성','목성','토성','천왕성','해왕성']
del solarsys[1:3]
print(solarsys)
# Out:
# ['태양', '지구', '화성', '목성', '토성', '천왕성', '해왕성']
