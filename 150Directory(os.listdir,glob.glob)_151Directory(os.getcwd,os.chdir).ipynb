# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/150Directory(os.listdir%2Cglob.glob)_151Directory(os.getcwd%2Cos.chdir).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 150 예제
import os,glob

folder='d:/devlab/py200'
file_list=os.listdir(folder)
print(file_list)

files='*.txt'
file_list=glob.glob(files)
print(file_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-469576096.py in <cell line: 0>()
#       3
#       4 folder='d:/devlab/py200'
# ----> 5 file_list=os.listdir(folder)
#       6 print(file_list)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:/devlab/py200'

# %%
#Unite 151 예제
import os

pdir=os.getcwd();print(pdir)
os.chdir('..');print(os.getcwd())
os.chdir('pdir');print(os.getcwd())
# Out:
# /content
# /
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1925549486.py in <cell line: 0>()
#       4 pdir=os.getcwd();print(pdir)
#       5 os.chdir('..');print(os.getcwd())
# ----> 6 os.chdir('pdir');print(os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pdir'
