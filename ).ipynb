# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 135 예제
add=lambda x,y:x+y
ret=add(1,3)
print(ret)

funcs=[lambda x:x+'.pptx',lambda x:x+'.docx']
ret1=funcs[0]('intro')
ret2=funcs[1]('Report')
print(ret1)
print(ret2)

names={'Mary':10999,'Sams':2111,'Aimy':9778,'Tom':20245,'Michale':27115,'Bob':5887,'Kelly':7855}
ret3=sorted(names.items(),key=lambda x:x[0])
print(ret3)
# Out:
# 4
# intro.pptx
# Report.docx
# [('Aimy', 9778), ('Bob', 5887), ('Kelly', 7855), ('Mary', 10999), ('Michale', 27115), ('Sams', 2111), ('Tom', 20245)]

# %%
#Unite 136 예제
f=lambda x:x*x
args=[1,2,3,4,5]
ret=map(f,args)
print(list(ret))
# Out:
# [1, 4, 9, 16, 25]
