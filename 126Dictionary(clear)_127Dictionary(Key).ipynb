# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/126Dictionary(clear)_127Dictionary(Key).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 126 예제
names={'Mary':10999,'Sams':2111,'Aimy':9778,'Tom':20245,'Michale':27115,'Bob':5887,'Kelly':7855}
names.clear()
print(names)
# Out:
# {}

# %%
#Unite 127 예제
names={'Mary':10999,'Sams':2111,'Aimy':9778,'Tom':20245,'Michale':27115,'Bob':5887,'Kelly':7855}
ks=names.keys()
print(ks)

for k in ks:
  print('Key:%s \tValue:%d'%(k,names[k]))
# Out:
# dict_keys(['Mary', 'Sams', 'Aimy', 'Tom', 'Michale', 'Bob', 'Kelly'])
# Key:Mary 	Value:10999
# Key:Sams 	Value:2111
# Key:Aimy 	Value:9778
# Key:Tom 	Value:20245
# Key:Michale 	Value:27115
# Key:Bob 	Value:5887
# Key:Kelly 	Value:7855
