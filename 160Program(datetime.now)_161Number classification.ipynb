# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/160Program(datetime.now)_161Number%20classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 160 예제
from datetime import datetime

start=datetime.now()
print('1에서 백만까지 더합니다.')
ret=0
for i in range(1000001):
  ret+=i
print('1에서 백만까지 더한 결과:%d'%ret)
end=datetime.now()
elapsed=end-start
print('총 계산 시간:',end='');print(elapsed)
elapsed_ms=int(elapsed.total_seconds()*1000)
print('총 계산 시간:%dms'%elapsed_ms)
# Out:
# 1에서 백만까지 더합니다.
# 1에서 백만까지 더한 결과:500000500000
# 총 계산 시간:0:00:00.144272
# 총 계산 시간:144ms

# %%
#Unite 161 예제
num=input('아무 숫자를 압력하세요')

if num.isdigit():
  num=num[::-1]
  ret=''
  for i,c in enumerate(num):
    i+=1
    if i !=len(num)and 1%3==0:
      ret+=(c+',')
    else:
      ret+=c
  ret=ret[::-1]
  print(ret)
else:
  print('입력한 내용[%s]:숫자가 아닙니다.'%num)
# Out:
# 아무 숫자를 압력하세요아
# 입력한 내용[아]:숫자가 아닙니다.
