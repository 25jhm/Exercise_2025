# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/136Recurring%20functions(map)_137Text%20file(read).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 136 예제
f=lambda x:x*x
args=[1,2,3,4,5]
ret=map(f,args)
print(list(ret))
# Out:
# [1, 4, 9, 16, 25]

# %%
#Unite 137 예제
f=open('stockcode.txt','r')
data=f.read()
print(data)
f.close()
#에러가 난 이유:stockcode.txt라는 함수가 노트북 디스크에 없어서
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1759744311.py in <cell line: 0>()
#       1 #Unite 137 예제
# ----> 2 f=open('stockcode.txt','r')
#       3 data=f.read()
#       4 print(data)
#       5 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stockcode.txt'
