# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/120List(enumerate)_121List(sum).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 120 예제
solarsys=['태양','수성','금성','지구','화성','목성','토성','청왕성','해왕성']
ret=list(enumerate(solarsys))
print(ret)

for i,body in enumerate(solarsys):
  print('태양계의 %d번째 천재:%s'%(i,body))
# Out:
# [(0, '태양'), (1, '수성'), (2, '금성'), (3, '지구'), (4, '화성'), (5, '목성'), (6, '토성'), (7, '청왕성'), (8, '해왕성')]
# 태양계의 0번째 천재:태양
# 태양계의 1번째 천재:수성
# 태양계의 2번째 천재:금성
# 태양계의 3번째 천재:지구
# 태양계의 4번째 천재:화성
# 태양계의 5번째 천재:목성
# 태양계의 6번째 천재:토성
# 태양계의 7번째 천재:청왕성
# 태양계의 8번째 천재:해왕성

# %%
#Unite 121 예제
listdata=[2,2,1,3,8,5,7,6,3,6,2,3,9,4,4]
ret=sum(listdata)
print(ret)
# Out:
# 65
