# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/116List(del)_117List(sort).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 116 예제
listdata=[2,2,1,3,8,5,7,6,3,6,2,3,9,4,4]
del listdata
print(listdata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4276245242.py in <cell line: 0>()
#       2 listdata=[2,2,1,3,8,5,7,6,3,6,2,3,9,4,4]
#       3 del listdata
# ----> 4 print(listdata)
#
# NameError: name 'listdata' is not defined

# %%
#Unite 117 예제
namelist=['Mary','Sams','Aimy','Tom','Michale','Bob','Keiiy']
namelist.sort()
print(namelist)
# Out:
# ['Aimy', 'Bob', 'Keiiy', 'Mary', 'Michale', 'Sams', 'Tom']
