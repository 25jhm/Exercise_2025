# %% [markdown]
# <a href="https://colab.research.google.com/github/25jhm/Exercise_2025/blob/main/137Text%20file(read)_138Text%20file(readline).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Unite 137 예제
f=open('stockcode.txt','r')
data=f.read()
print(data)
f.close()
#에러가 난 이유:stockcode.txt라는 함수가 노트북 디스크에 없어서
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3947265891.py in <cell line: 0>()
#       1 #Unite 137 예제
# ----> 2 f=open('stockcode.txt','r')
#       3 data=f.read()
#       4 print(data)
#       5 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stockcode.txt'

# %%
#Unite 138 예제
f=open('stockcode.txt','r')
line_num=1
line=f.readline()
while line:
  print('%d %s'%(line_num,line),end='')
  line=f.readline()
  line_num+=1
f.close
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-379582660.py in <cell line: 0>()
#       1 #Unite 138 예제
# ----> 2 f=open('stockcode.txt','r')
#       3 line_num=1
#       4 line=f.readline()
#       5 while line:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stockcode.txt'
